# %%
import numpy as np
from scipy.spatial import distance
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import pandas as pd
from matplotlib import pyplot as plt
import pickle
from numpy.random import default_rng

# %%
seed = 0
np.random.seed(seed)

# %%
train_file = 'data/OliveOil_TRAIN'

# %%
test_file = 'data/OliveOil_TEST'

# %%
sampling_rate = 5

# %% [markdown]
# # Prep Train Data

# %%
train_data = np.loadtxt(train_file)

# %%
rng = default_rng(12345)
rng.shuffle(train_data)

# %%
X_train = train_data[:,1:]

# %%
y_train = train_data[:,0]

# %%
print(X_train[0])
# Out:
# [0.130412 0.130675 0.132017 0.133824 0.136095 0.138944 0.141723 0.144136
#  0.146431 0.148389 0.149837 0.151585 0.15398  0.156724 0.15945  0.162588
#  0.165934 0.169093 0.172397 0.175715 0.179491 0.183787 0.188501 0.193575
#  0.198566 0.202986 0.206671 0.209261 0.211073 0.211925 0.211514 0.210548
#  0.209608 0.209355 0.209861 0.210734 0.211455 0.211714 0.21137  0.210273
#  0.208276 0.205723 0.20332  0.201692 0.200819 0.200697 0.201472 0.201889
#  0.201266 0.199871 0.197954 0.196582 0.195869 0.195901 0.196148 0.196098
#  0.195735 0.194873 0.194042 0.193285 0.19214  0.190683 0.189272 0.18781
#  0.186543 0.185897 0.185932 0.186857 0.188657 0.191872 0.196667 0.202137
#  0.207723 0.213356 0.218849 0.224527 0.230611 0.236364 0.24177  0.247225
#  0.25281  0.258557 0.264376 0.269652 0.274173 0.277536 0.279723 0.28077
#  0.280131 0.278214 0.275684 0.273349 0.271849 0.271867 0.273442 0.275535
#  0.277191 0.278099 0.278728 0.279492 0.280641 0.282266 0.284711 0.287662
#  0.291062 0.294744 0.298298 0.302238 0.306366 0.310681 0.315258 0.320408
#  0.326108 0.332095 0.338592 0.344819 0.350317 0.354893 0.35864  0.361313
#  0.362642 0.362785 0.361068 0.357315 0.352135 0.346277 0.341222 0.338763
#  0.340069 0.345142 0.353103 0.363961 0.376651 0.389081 0.400582 0.411173
#  0.420606 0.428736 0.435714 0.441745 0.448898 0.459472 0.475339 0.497432
#  0.525452 0.559168 0.596014 0.632222 0.665169 0.694875 0.72456  0.755435
#  0.784086 0.804479 0.813874 0.812573 0.80157  0.784073 0.763307 0.744836
#  0.737345 0.744333 0.765369 0.795578 0.826539 0.849266 0.857149 0.845324
#  0.815186 0.77941  0.751843 0.746008 0.769417 0.821727 0.896202 0.981979
#  1.06749  1.140728 1.194336 1.228316 1.250618 1.269967 1.293141 1.320587
#  1.350189 1.376685 1.396897 1.406391 1.405476 1.396938 1.375255 1.343045
#  1.305949 1.262988 1.216782 1.168853 1.121548 1.076026 1.032274 0.990618
#  0.951423 0.914026 0.878556 0.845377 0.813883 0.782897 0.752158 0.723731
#  0.698854 0.677825 0.661185 0.648992 0.640401 0.634245 0.629125 0.624742
#  0.621537 0.620879 0.624007 0.630058 0.637915 0.647077 0.656855 0.666113
#  0.674284 0.680955 0.686347 0.689747 0.689339 0.683247 0.671408 0.654173
#  0.042947 0.040581 0.038335 0.036353 0.034461 0.03262  0.03074  0.029236
#  0.027885 0.026924 0.025832 0.024729 0.023741 0.022638 0.021665 0.020757
#  0.019743 0.018618 0.017688 0.016749 0.015845 0.015033 0.014065 0.013655
#  0.013521 0.013021 0.012455 0.011928 0.01145  0.0112   0.01095  0.010546
#  0.009796 0.009225 0.00897  0.0087   0.008355 0.008194 0.008232 0.008142
#  0.00777  0.007493 0.007512 0.007548 0.007391 0.007176 0.006843 0.006551
#  0.006398 0.006582]

# %%
print(y_train)
# Out:
# [1. 2. 4. 3. 4. 4. 2. 4. 4. 2. 1. 2. 2. 4. 2. 4. 4. 1. 4. 2. 1. 2. 4. 3.
#  3. 1. 4. 4. 3. 4.]

# %%
X_train.shape
# Out:
# (30, 570)

# %%
y_train.shape
# Out:
# (30,)

# %%
plt.plot(X_train[1])
plt.show()

# %%
plt.plot(X_train[1, ::sampling_rate])
plt.show()

# %%
X_train_sampling = X_train[:, ::sampling_rate]

# %%
X_train_sampling.shape
# Out:
# (30, 114)

# %% [markdown]
# # Prep Test Data

# %%
test_data = np.loadtxt(test_file)

# %%
rng = default_rng(12345)
rng.shuffle(test_data)

# %%
X_test = test_data[:,1:]

# %%
y_test = test_data[:,0]

# %%
print(X_test[0])
# Out:
# [0.127523 0.12795  0.129282 0.131174 0.13359  0.136426 0.139358 0.142219
#  0.144805 0.146764 0.148192 0.149937 0.152373 0.15505  0.157988 0.160809
#  0.1638   0.16725  0.170812 0.174319 0.177914 0.182091 0.186707 0.191972
#  0.197008 0.201373 0.205442 0.20848  0.209952 0.210486 0.210038 0.209084
#  0.208712 0.208768 0.209268 0.210113 0.211027 0.211241 0.210671 0.209317
#  0.207287 0.204825 0.202283 0.200652 0.19995  0.199845 0.20049  0.20086
#  0.200056 0.198513 0.196763 0.195297 0.19466  0.194683 0.194877 0.195093
#  0.19474  0.193703 0.19262  0.191565 0.190422 0.189213 0.187734 0.18619
#  0.184788 0.183765 0.183669 0.184534 0.186481 0.19     0.194675 0.199888
#  0.205518 0.211487 0.217381 0.222963 0.228657 0.234344 0.239728 0.245155
#  0.250866 0.256754 0.262744 0.268176 0.272617 0.275863 0.277633 0.278133
#  0.277478 0.275924 0.273717 0.271731 0.270607 0.270951 0.272717 0.274612
#  0.2762   0.277373 0.278297 0.279282 0.280706 0.282665 0.284927 0.28774
#  0.291205 0.294984 0.298792 0.302848 0.307245 0.311715 0.316094 0.320912
#  0.326774 0.333143 0.339463 0.345577 0.350907 0.355264 0.359038 0.362094
#  0.363898 0.364119 0.362461 0.358624 0.353316 0.347389 0.342287 0.339873
#  0.341116 0.346235 0.354628 0.365465 0.377867 0.390502 0.402365 0.413147
#  0.422848 0.431425 0.438514 0.444581 0.451694 0.462293 0.477998 0.499991
#  0.528229 0.56151  0.597958 0.63426  0.667394 0.697479 0.727459 0.758506
#  0.78756  0.808478 0.818079 0.816345 0.804923 0.786736 0.765774 0.748482
#  0.054702 0.060711 0.063644 0.066034 0.068338 0.068084 0.064837 0.060878
#  0.05699  0.054046 0.052925 0.052809 0.053079 0.053952 0.055188 0.057304
#  0.059254 0.062031 0.06503  0.069304 0.07399  0.077032 0.081597 0.086338
#  0.091703 0.099157 0.109624 0.116327 0.129308 0.137527 0.145631 0.154361
#  0.16151  0.170421 0.180782 0.197086 0.21747  0.247376 0.275534 0.310427
#  0.362963 0.427579 0.506659 0.615776 0.738786 0.864576 1.132739 1.277696
#  1.408618 1.49504  1.568707 1.549912 1.496467 1.345538 1.214856 1.064078
#  0.927809 0.724714 0.578206 0.464635 0.35002  0.283923 0.2384   0.19596
#  0.170609 0.14565  0.126315 0.113675 0.103045 0.094274 0.085652 0.079768
#  0.073591 0.068943 0.065328 0.061819 0.057799 0.055023 0.052152 0.049723
#  0.047094 0.044839 0.042668 0.040562 0.038699 0.036817 0.034879 0.033546
#  0.03234  0.031043 0.029902 0.029063 0.02808  0.027107 0.026468 0.025241
#  0.024099 0.02314  0.022068 0.02106  0.020088 0.019414 0.018799 0.018205
#  0.01778  0.017431 0.017043 0.016623 0.016091 0.015719 0.015344 0.01495
#  0.014523 0.014027 0.013501 0.01313  0.013274 0.013091 0.012746 0.012758
#  0.012652 0.012395 0.012269 0.012279 0.012158 0.011884 0.011716 0.011583
#  0.011315 0.011304]

# %%
print(y_test[0])
# Out:
# 1.0

# %%
X_test_sampling = X_test[:, ::sampling_rate]

# %%
X_test_sampling.shape
# Out:
# (30, 114)

# %%
plt.plot(X_test[1])
plt.show()

# %%
plt.plot(X_test_sampling[0])
plt.show()

# %% [markdown]
# # Train Model

# %%
def DTW(a, b):
    # ถ้า DTW  ทำช้าอาจต้องทำ sampling เพื่อลดปริมาณ data ทำ DTW จะได้เร็วขึ้น    
    an = a.size
    bn = b.size
    pointwise_distance = distance.cdist(a.reshape(-1,1),b.reshape(-1,1))
    cumdist = np.matrix(np.ones((an+1,bn+1)) * np.inf)
    cumdist[0,0] = 0
    
    for ai in range(an):
        for bi in range(bn):
            minimum_cost = np.min([cumdist[ai, bi+1],
                                   cumdist[ai+1, bi],
                                   cumdist[ai, bi]])
            cumdist[ai+1, bi+1] = pointwise_distance[ai,bi] + minimum_cost

    return cumdist[an, bn]

# %%
def DTWWithWeightNeighborCell(a,b,**kwargs):
    # print("weight",kwargs["alpha"],kwargs["beta"],kwargs["gamma"])
    an = a.size
    bn = b.size
    pointwise_distance = distance.cdist(a.reshape(-1,1),b.reshape(-1,1))
    cumdist = np.matrix(np.ones((an+1,bn+1)) * np.inf)
    cumdist[0,0] = 0
    
    for ai in range(an):
        for bi in range(bn):
            minimum_cost = np.min([kwargs["alpha"]*cumdist[ai, bi+1],
                                   kwargs["beta"]*cumdist[ai, bi],
                                   kwargs["gamma"]*cumdist[ai+1, bi]])
            cumdist[ai+1, bi+1] = pointwise_distance[ai,bi] + minimum_cost

    return cumdist[an, bn]

# %% [markdown]
# # Test Symmetric Model

# %%
clf = KNeighborsClassifier(metric =DTW,n_neighbors=1,n_jobs=-1)
clf.fit(X_train_sampling, y_train)
# Out:
# KNeighborsClassifier(metric=<function DTW at 0x00000264E0C04F70>, n_jobs=-1,
#                      n_neighbors=1)

# %%
y_pred = clf.predict(X_test_sampling)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.80      0.80      0.80         5
#          2.0       0.75      1.00      0.86         9
#          3.0       1.00      0.25      0.40         4
#          4.0       0.92      0.92      0.92        12
#
#     accuracy                           0.83        30
#    macro avg       0.87      0.74      0.74        30
# weighted avg       0.86      0.83      0.81        30

# %% [markdown]
# # Create Model with weight neighboring cells [Test Asymmetric]

# %%
def createMetricParams(alphaMax,betaMax,gammaMax):
    metricParamsArray = []
    for i in range(1,alphaMax+1):
        for j in range(1,betaMax+1):
            for k in range(1,gammaMax+1):
                if (i == k):
                    continue
                metricParam = {"alpha":i,"beta":j,"gamma":k}
                metricParamsArray.append(metricParam)
    return metricParamsArray

# %%
createMetricParams(2,2,2)
# Out:
# [{'alpha': 1, 'beta': 1, 'gamma': 2},
#  {'alpha': 1, 'beta': 2, 'gamma': 2},
#  {'alpha': 2, 'beta': 1, 'gamma': 1},
#  {'alpha': 2, 'beta': 2, 'gamma': 1}]

# %%
parameters = {'n_neighbors':[1],'metric_params':createMetricParams(5,5,5)}
clf = GridSearchCV(KNeighborsClassifier(metric =DTWWithWeightNeighborCell), parameters, cv=2,verbose=10,n_jobs=-1)
clf.fit(X_train_sampling, y_train)
# Out:
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# GridSearchCV(cv=2,
#              estimator=KNeighborsClassifier(metric=<function DTWWithWeightNeighborCell at 0x00000264DD79F2E0>),
#              n_jobs=-1,
#              param_grid={'metric_params': [{'alpha': 1, 'beta': 1, 'gamma': 2},
#                                            {'alpha': 1, 'beta': 1, 'gamma': 3},
#                                            {'alpha': 1, 'beta': 1, 'gamma': 4},
#                                            {'alpha': 1, 'beta': 1, 'gamma': 5},
#                                            {'alpha': 1, 'beta': 2, 'gamma': 2},
#                                            {'alpha': 1, 'beta': 2, 'gamma': 3},
#                                            {'alpha': 1, '...
#                                            {'alpha': 1, 'beta': 5, 'gamma': 5},
#                                            {'alpha': 2, 'beta': 1, 'gamma': 1},
#                                            {'alpha': 2, 'beta': 1, 'gamma': 3},
#                                            {'alpha': 2, 'beta': 1, 'gamma': 4},
#                                            {'alpha': 2, 'beta': 1, 'gamma': 5},
#                                            {'alpha': 2, 'beta': 2, 'gamma': 1},
#                                            {'alpha': 2, 'beta': 2, 'gamma': 3},
#                                            {'alpha': 2, 'beta': 2, 'gamma': 4},
#                                            {'alpha': 2, 'beta': 2, 'gamma': 5},
#                                            {'alpha': 2, 'beta': 3, 'gamma': 1},
#                                            {'alpha': 2, 'beta': 3, 'gamma': 3}, ...],
#                          'n_neighbors': [1]},
#              verbose=10)

# %%
grid_search_result = clf.cv_results_
grid_search_result_pd = pd.DataFrame.from_dict(grid_search_result)

# %%
grid_search_result_pd
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001494  4.938841e-04        66.111476        0.781995
# 1        0.002007  2.264977e-06        66.390968        0.966509
# 2        0.001994  9.988546e-04        65.715977        0.413498
# 3        0.001509  4.954338e-04        65.296967        0.203489
# 4        0.001005  9.179115e-06        66.742966        1.217494
# ..            ...           ...              ...             ...
# 95       0.000999  8.344650e-07        82.175441        0.439644
# 96       0.001000  1.072884e-06        51.830376        0.433306
# 97       0.001499  4.980564e-04        50.422572        0.228502
# 98       0.001497  4.981756e-04        50.366577        0.160504
# 99       0.001001  8.344650e-07        49.835585        0.199495
#
#                     param_metric_params param_n_neighbors  \
# 0   {'alpha': 1, 'beta': 1, 'gamma': 2}                 1
# 1   {'alpha': 1, 'beta': 1, 'gamma': 3}                 1
# 2   {'alpha': 1, 'beta': 1, 'gamma': 4}                 1
# 3   {'alpha': 1, 'beta': 1, 'gamma': 5}                 1
# 4   {'alpha': 1, 'beta': 2, 'gamma': 2}                 1
# ..                                  ...               ...
# 95  {'alpha': 5, 'beta': 4, 'gamma': 4}                 1
# 96  {'alpha': 5, 'beta': 5, 'gamma': 1}                 1
# 97  {'alpha': 5, 'beta': 5, 'gamma': 2}                 1
# 98  {'alpha': 5, 'beta': 5, 'gamma': 3}                 1
# 99  {'alpha': 5, 'beta': 5, 'gamma': 4}                 1
#
#                                                params  split0_test_score  \
# 0   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.800000
# 1   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.800000
# 2   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.800000
# 3   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.800000
# 4   {'metric_params': {'alpha': 1, 'beta': 2, 'gam...           0.333333
# ..                                                ...                ...
# 95  {'metric_params': {'alpha': 5, 'beta': 4, 'gam...           0.333333
# 96  {'metric_params': {'alpha': 5, 'beta': 5, 'gam...           0.333333
# 97  {'metric_params': {'alpha': 5, 'beta': 5, 'gam...           0.333333
# 98  {'metric_params': {'alpha': 5, 'beta': 5, 'gam...           0.333333
# 99  {'metric_params': {'alpha': 5, 'beta': 5, 'gam...           0.333333
#
#     split1_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.800000         0.800000             0.0                1
# 1            0.800000         0.800000             0.0                1
# 2            0.800000         0.800000             0.0                1
# 3            0.800000         0.800000             0.0                1
# 4            0.533333         0.433333             0.1               21
# ..                ...              ...             ...              ...
# 95           0.533333         0.433333             0.1               21
# 96           0.533333         0.433333             0.1               21
# 97           0.533333         0.433333             0.1               21
# 98           0.533333         0.433333             0.1               21
# 99           0.533333         0.433333             0.1               21
#
# [100 rows x 12 columns]

# %%
grid_search_result_pd[grid_search_result_pd['rank_test_score'] == 1]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001494  4.938841e-04        66.111476        0.781995
# 1        0.002007  2.264977e-06        66.390968        0.966509
# 2        0.001994  9.988546e-04        65.715977        0.413498
# 3        0.001509  4.954338e-04        65.296967        0.203489
# 20       0.001000  1.192093e-06        69.490052        0.972758
# 21       0.001004  9.536743e-07        69.943051        0.555760
# 22       0.001003  2.384186e-06        70.394870        0.630578
# 23       0.001000  3.337860e-06        70.454632        0.064820
# 40       0.000998  1.311302e-06        76.108251        0.137679
# 41       0.001499  5.023479e-04        76.502595        0.220292
# 42       0.000000  0.000000e+00        76.180300        0.097000
# 43       0.001001  3.576279e-07        76.918538        0.255577
# 60       0.001506  4.961491e-04        80.512407        0.513504
# 61       0.002502  1.498938e-03        79.788410        0.424503
# 62       0.001001  1.549721e-06        79.347450        0.345001
# 63       0.001001  2.384186e-06        79.853279        0.375000
# 80       0.001001  5.960464e-07        82.270480        0.088001
# 81       0.002000  9.989738e-04        82.294275        0.585797
# 82       0.001500  4.969835e-04        82.346536        0.098001
# 83       0.000996  2.622604e-06        82.348459        0.060495
#
#                     param_metric_params param_n_neighbors  \
# 0   {'alpha': 1, 'beta': 1, 'gamma': 2}                 1
# 1   {'alpha': 1, 'beta': 1, 'gamma': 3}                 1
# 2   {'alpha': 1, 'beta': 1, 'gamma': 4}                 1
# 3   {'alpha': 1, 'beta': 1, 'gamma': 5}                 1
# 20  {'alpha': 2, 'beta': 1, 'gamma': 1}                 1
# 21  {'alpha': 2, 'beta': 1, 'gamma': 3}                 1
# 22  {'alpha': 2, 'beta': 1, 'gamma': 4}                 1
# 23  {'alpha': 2, 'beta': 1, 'gamma': 5}                 1
# 40  {'alpha': 3, 'beta': 1, 'gamma': 1}                 1
# 41  {'alpha': 3, 'beta': 1, 'gamma': 2}                 1
# 42  {'alpha': 3, 'beta': 1, 'gamma': 4}                 1
# 43  {'alpha': 3, 'beta': 1, 'gamma': 5}                 1
# 60  {'alpha': 4, 'beta': 1, 'gamma': 1}                 1
# 61  {'alpha': 4, 'beta': 1, 'gamma': 2}                 1
# 62  {'alpha': 4, 'beta': 1, 'gamma': 3}                 1
# 63  {'alpha': 4, 'beta': 1, 'gamma': 5}                 1
# 80  {'alpha': 5, 'beta': 1, 'gamma': 1}                 1
# 81  {'alpha': 5, 'beta': 1, 'gamma': 2}                 1
# 82  {'alpha': 5, 'beta': 1, 'gamma': 3}                 1
# 83  {'alpha': 5, 'beta': 1, 'gamma': 4}                 1
#
#                                                params  split0_test_score  \
# 0   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...                0.8
# 1   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...                0.8
# 2   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...                0.8
# 3   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...                0.8
# 20  {'metric_params': {'alpha': 2, 'beta': 1, 'gam...                0.8
# 21  {'metric_params': {'alpha': 2, 'beta': 1, 'gam...                0.8
# 22  {'metric_params': {'alpha': 2, 'beta': 1, 'gam...                0.8
# 23  {'metric_params': {'alpha': 2, 'beta': 1, 'gam...                0.8
# 40  {'metric_params': {'alpha': 3, 'beta': 1, 'gam...                0.8
# 41  {'metric_params': {'alpha': 3, 'beta': 1, 'gam...                0.8
# 42  {'metric_params': {'alpha': 3, 'beta': 1, 'gam...                0.8
# 43  {'metric_params': {'alpha': 3, 'beta': 1, 'gam...                0.8
# 60  {'metric_params': {'alpha': 4, 'beta': 1, 'gam...                0.8
# 61  {'metric_params': {'alpha': 4, 'beta': 1, 'gam...                0.8
# 62  {'metric_params': {'alpha': 4, 'beta': 1, 'gam...                0.8
# 63  {'metric_params': {'alpha': 4, 'beta': 1, 'gam...                0.8
# 80  {'metric_params': {'alpha': 5, 'beta': 1, 'gam...                0.8
# 81  {'metric_params': {'alpha': 5, 'beta': 1, 'gam...                0.8
# 82  {'metric_params': {'alpha': 5, 'beta': 1, 'gam...                0.8
# 83  {'metric_params': {'alpha': 5, 'beta': 1, 'gam...                0.8
#
#     split1_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.8              0.8             0.0                1
# 1                 0.8              0.8             0.0                1
# 2                 0.8              0.8             0.0                1
# 3                 0.8              0.8             0.0                1
# 20                0.8              0.8             0.0                1
# 21                0.8              0.8             0.0                1
# 22                0.8              0.8             0.0                1
# 23                0.8              0.8             0.0                1
# 40                0.8              0.8             0.0                1
# 41                0.8              0.8             0.0                1
# 42                0.8              0.8             0.0                1
# 43                0.8              0.8             0.0                1
# 60                0.8              0.8             0.0                1
# 61                0.8              0.8             0.0                1
# 62                0.8              0.8             0.0                1
# 63                0.8              0.8             0.0                1
# 80                0.8              0.8             0.0                1
# 81                0.8              0.8             0.0                1
# 82                0.8              0.8             0.0                1
# 83                0.8              0.8             0.0                1

# %%
model = clf.best_estimator_

# %%
print(model.get_params)
# Out:
# <bound method BaseEstimator.get_params of KNeighborsClassifier(metric=<function DTWWithWeightNeighborCell at 0x00000264DD79F2E0>,
#                      metric_params={'alpha': 1, 'beta': 1, 'gamma': 2},
#                      n_neighbors=1)>

# %%
y_pred = model.predict(X_test_sampling)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.83      1.00      0.91         5
#          2.0       0.82      1.00      0.90         9
#          3.0       1.00      0.25      0.40         4
#          4.0       0.92      0.92      0.92        12
#
#     accuracy                           0.87        30
#    macro avg       0.89      0.79      0.78        30
# weighted avg       0.88      0.87      0.84        30

# %% [markdown]
# Dump Best Asym Model

# %%
model_file = open('knn_Best_Asym_OliveOil.model', 'wb')
pickle.dump(model, model_file)
model_file.close()

# %% [markdown]
# จาก db OliveOil เราจะเห็นว่า Best ของ Asymmetric accuracy ดีกว่า Symmetric
