# %%
import numpy as np
from scipy.spatial import distance
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import pandas as pd
from matplotlib import pyplot as plt
import pickle

# %%
seed = 0
np.random.seed(seed)

# %%
train_file = 'data/OliveOil_TRAIN'

# %%
test_file = 'data/OliveOil_TEST'

# %%
sampling_rate = 5

# %% [markdown]
# # Prep Train Data

# %%
train_data = np.loadtxt(train_file)

# %%
np.random.shuffle(train_data)

# %%
X_train = train_data[:,1:]

# %%
y_train = train_data[:,0]

# %%
print(X_train[0])
# Out:
# [0.12701  0.127513 0.128898 0.130888 0.133359 0.13599  0.138718 0.141501
#  0.143928 0.145775 0.147318 0.148985 0.151271 0.15403  0.157017 0.160163
#  0.163241 0.166489 0.169942 0.173267 0.177275 0.181909 0.186561 0.191507
#  0.196476 0.20097  0.204591 0.207341 0.209083 0.209798 0.209505 0.2087
#  0.207617 0.207488 0.20841  0.209193 0.210046 0.210548 0.210022 0.208642
#  0.206532 0.204012 0.201796 0.200154 0.19908  0.19896  0.1997   0.199976
#  0.199146 0.19774  0.196311 0.195068 0.194278 0.194065 0.194048 0.19421
#  0.194088 0.193188 0.192169 0.191218 0.190162 0.189086 0.187607 0.185788
#  0.184331 0.183403 0.18325  0.184255 0.186454 0.189703 0.194226 0.199728
#  0.205367 0.210962 0.216632 0.222418 0.228207 0.233907 0.239389 0.244858
#  0.250841 0.257138 0.263133 0.26866  0.273307 0.276709 0.279024 0.279924
#  0.279419 0.277645 0.275251 0.272706 0.271091 0.271338 0.27267  0.274463
#  0.276261 0.277314 0.277811 0.278596 0.27991  0.281501 0.283904 0.287135
#  0.290572 0.293982 0.297817 0.302221 0.306359 0.310593 0.315194 0.320246
#  0.325856 0.332259 0.338983 0.345378 0.350874 0.354968 0.358655 0.361552
#  0.363136 0.363409 0.36153  0.357687 0.352324 0.346387 0.341612 0.339445
#  0.340931 0.345817 0.353926 0.364925 0.377603 0.390518 0.402059 0.412399
#  0.422121 0.430699 0.437496 0.443395 0.450633 0.46107  0.476653 0.498548
#  0.526931 0.560393 0.59679  0.633187 0.666552 0.696678 0.726609 0.757326
#  0.786351 0.808178 0.818003 0.816547 0.805949 0.787979 0.766914 0.74896
#  0.741721 0.748958 0.76898  0.799081 0.830851 0.853462 0.860271 0.847529
#  0.817572 0.781681 0.754435 0.748136 0.771365 0.824238 0.899546 0.987469
#  1.073807 1.145936 1.199233 1.234549 1.258296 1.279573 1.302358 1.328443
#  1.356334 1.380888 1.40047  1.412794 1.416542 1.406092 1.380504 1.347799
#  1.311583 1.269106 1.22129  1.172248 1.126215 1.080063 1.034824 0.992071
#  0.952379 0.915563 0.879603 0.845565 0.8138   0.782157 0.751792 0.723774
#  0.69897  0.677976 0.660605 0.648328 0.639998 0.633725 0.628641 0.624111
#  0.621359 0.621414 0.624313 0.630097 0.638394 0.648126 0.657843 0.666792
#  0.675011 0.681814 0.686797 0.690294 0.690201 0.683927 0.672048 0.654586
#  0.631965 0.605926 0.580891 0.560604 0.546271 0.536186 0.528025 0.519707
#  0.015637 0.014614 0.013474 0.012378 0.011428 0.010555 0.009894 0.009758
#  0.009492 0.008904 0.008304 0.007973 0.007583 0.007039 0.006456 0.006124
#  0.005783 0.005184 0.004506 0.004359 0.004389 0.004259 0.004137 0.003899
#  0.003651 0.003601 0.0035   0.003299 0.003043 0.002567 0.002445 0.00247
#  0.00216  0.002193]

# %%
print(y_train)
# Out:
# [1. 4. 3. 2. 4. 4. 4. 2. 4. 4. 2. 3. 2. 3. 4. 4. 1. 4. 2. 1. 4. 4. 2. 2.
#  4. 1. 1. 4. 3. 2.]

# %%
X_train.shape
# Out:
# (30, 570)

# %%
y_train.shape
# Out:
# (30,)

# %%
plt.plot(X_train[1])
plt.show()

# %%
plt.plot(X_train[1, ::sampling_rate])
plt.show()

# %%
X_train_sampling = X_train[:, ::sampling_rate]

# %%
X_train_sampling.shape
# Out:
# (30, 114)

# %% [markdown]
# # Prep Test Data

# %%
test_data = np.loadtxt(test_file)

# %%
np.random.shuffle(test_data)

# %%
X_test = test_data[:,1:]

# %%
y_test = test_data[:,0]

# %%
print(X_test[0])
# Out:
# [0.128413 0.128769 0.130012 0.131938 0.134329 0.136944 0.139649 0.142251
#  0.144782 0.146844 0.148578 0.150601 0.152757 0.155544 0.159008 0.162506
#  0.165689 0.169021 0.17219  0.175492 0.179571 0.183948 0.188764 0.193898
#  0.19871  0.202833 0.206347 0.209317 0.210929 0.211224 0.210802 0.20982
#  0.209156 0.209376 0.210068 0.21105  0.212068 0.212298 0.211997 0.21092
#  0.208763 0.206022 0.203663 0.202181 0.201263 0.201217 0.20168  0.201932
#  0.201151 0.199634 0.19817  0.197022 0.196566 0.196739 0.197215 0.197664
#  0.197804 0.197553 0.197004 0.196357 0.195484 0.194231 0.192504 0.190183
#  0.187869 0.186423 0.185961 0.186296 0.187986 0.191199 0.195443 0.200488
#  0.206161 0.212193 0.218122 0.223706 0.229389 0.23524  0.241034 0.246899
#  0.25284  0.258731 0.264546 0.26976  0.273815 0.276592 0.278133 0.278494
#  0.277647 0.27616  0.274147 0.272003 0.270832 0.271347 0.27306  0.275261
#  0.27721  0.278197 0.278962 0.279959 0.281197 0.282749 0.285015 0.287956
#  0.291276 0.295162 0.299118 0.302966 0.307277 0.311465 0.315646 0.320564
#  0.326136 0.33264  0.339487 0.346263 0.352166 0.356842 0.360266 0.362922
#  0.364922 0.365174 0.363947 0.360758 0.355505 0.349374 0.34449  0.342365
#  0.343719 0.348894 0.357447 0.368511 0.381249 0.394306 0.405916 0.416423
#  0.426072 0.434112 0.440682 0.446427 0.453381 0.463565 0.479053 0.500811
#  0.529278 0.563725 0.601046 0.638091 0.671648 0.701576 0.731531 0.762591
#  0.791296 0.812831 0.82281  0.820877 0.810446 0.792896 0.770771 0.750246
#  0.740242 0.745761 0.76517  0.793543 0.824375 0.848341 0.857417 0.846369
#  0.818418 0.784439 0.757479 0.753067 0.778308 0.832126 0.908602 0.996601
#  1.08143  1.151981 1.203448 1.236219 1.259127 1.277792 1.29917  1.326769
#  0.155537 0.16415  0.174139 0.190569 0.211868 0.243342 0.272654 0.309066
#  0.364301 0.430934 0.511455 0.622496 0.746921 0.872451 1.14361  1.290067
#  1.425694 1.507972 1.571046 1.546637 1.491225 1.344192 1.21642  1.06172
#  0.924051 0.720978 0.57463  0.461725 0.347656 0.281296 0.235446 0.192914
#  0.16801  0.142953 0.123165 0.110513 0.09997  0.09137  0.082786 0.0769
#  0.070846 0.066179 0.06235  0.058677 0.054999 0.05232  0.049499 0.047172
#  0.044418 0.041919 0.039679 0.037668 0.035719 0.033882 0.032343 0.031136
#  0.029664 0.028312 0.027253 0.026238 0.025226 0.024372 0.02337  0.022252
#  0.021517 0.020356 0.019238 0.018504 0.017426 0.016572 0.015934 0.015475
#  0.015119 0.014719 0.014239 0.013798 0.013383 0.012957 0.012467 0.012214
#  0.011776 0.010952 0.010371 0.010214 0.010325 0.01026  0.010093 0.009888
#  0.009547 0.009481 0.009433 0.00924  0.009189 0.008976 0.008675 0.008662
#  0.008465 0.008259]

# %%
print(y_test[0])
# Out:
# 2.0

# %%
X_test_sampling = X_test[:, ::sampling_rate]

# %%
X_test_sampling.shape
# Out:
# (30, 114)

# %%
plt.plot(X_test[1])
plt.show()

# %%
plt.plot(X_test_sampling[0])
plt.show()

# %% [markdown]
# # Train Model

# %%
def DTW(a, b):
    # ถ้า DTW  ทำช้าอาจต้องทำ sampling เพื่อลดปริมาณ data ทำ DTW จะได้เร็วขึ้น    
    an = a.size
    bn = b.size
    pointwise_distance = distance.cdist(a.reshape(-1,1),b.reshape(-1,1))
    cumdist = np.matrix(np.ones((an+1,bn+1)) * np.inf)
    cumdist[0,0] = 0
    
    for ai in range(an):
        for bi in range(bn):
            minimum_cost = np.min([cumdist[ai, bi+1],
                                   cumdist[ai+1, bi],
                                   cumdist[ai, bi]])
            cumdist[ai+1, bi+1] = pointwise_distance[ai,bi] + minimum_cost

    return cumdist[an, bn]

# %%
def DTWWithWeightNeighborCell(a,b,**kwargs):
    # print("weight",kwargs["alpha"],kwargs["beta"],kwargs["gamma"])
    an = a.size
    bn = b.size
    pointwise_distance = distance.cdist(a.reshape(-1,1),b.reshape(-1,1))
    cumdist = np.matrix(np.ones((an+1,bn+1)) * np.inf)
    cumdist[0,0] = 0
    
    for ai in range(an):
        for bi in range(bn):
            minimum_cost = np.min([kwargs["alpha"]*cumdist[ai, bi+1],
                                   kwargs["beta"]*cumdist[ai, bi],
                                   kwargs["gamma"]*cumdist[ai+1, bi]])
            cumdist[ai+1, bi+1] = pointwise_distance[ai,bi] + minimum_cost

    return cumdist[an, bn]

# %% [markdown]
# # Test Symmetric Model

# %%
clf = KNeighborsClassifier(metric =DTW,n_neighbors=1,n_jobs=-1)
clf.fit(X_train_sampling, y_train)
# Out:
# KNeighborsClassifier(metric=<function DTW at 0x00000264DD9756C0>, n_jobs=-1,
#                      n_neighbors=1)

# %%
y_pred = clf.predict(X_test_sampling)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.80      0.80      0.80         5
#          2.0       0.75      1.00      0.86         9
#          3.0       1.00      0.25      0.40         4
#          4.0       0.92      0.92      0.92        12
#
#     accuracy                           0.83        30
#    macro avg       0.87      0.74      0.74        30
# weighted avg       0.86      0.83      0.81        30

# %% [markdown]
# # Create Model with weight neighboring cells [Test Asymmetric]

# %%
def createMetricParams(alphaMax,betaMax,gammaMax):
    metricParamsArray = []
    for i in range(1,alphaMax+1):
        for j in range(1,betaMax+1):
            for k in range(1,gammaMax+1):
                if (i == k):
                    continue
                metricParam = {"alpha":i,"beta":j,"gamma":k}
                metricParamsArray.append(metricParam)
    return metricParamsArray

# %%
createMetricParams(2,2,2)
# Out:
# [{'alpha': 1, 'beta': 1, 'gamma': 2},
#  {'alpha': 1, 'beta': 2, 'gamma': 2},
#  {'alpha': 2, 'beta': 1, 'gamma': 1},
#  {'alpha': 2, 'beta': 2, 'gamma': 1}]

# %%
parameters = {'n_neighbors':[1],'metric_params':createMetricParams(5,5,5)}
clf = GridSearchCV(KNeighborsClassifier(metric =DTWWithWeightNeighborCell), parameters, cv=2,verbose=10,n_jobs=-1)
clf.fit(X_train_sampling, y_train)
# Out:
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# GridSearchCV(cv=2,
#              estimator=KNeighborsClassifier(metric=<function DTWWithWeightNeighborCell at 0x00000264DD976D40>),
#              n_jobs=-1,
#              param_grid={'metric_params': [{'alpha': 1, 'beta': 1, 'gamma': 2},
#                                            {'alpha': 1, 'beta': 1, 'gamma': 3},
#                                            {'alpha': 1, 'beta': 1, 'gamma': 4},
#                                            {'alpha': 1, 'beta': 1, 'gamma': 5},
#                                            {'alpha': 1, 'beta': 2, 'gamma': 2},
#                                            {'alpha': 1, 'beta': 2, 'gamma': 3},
#                                            {'alpha': 1, '...
#                                            {'alpha': 1, 'beta': 5, 'gamma': 5},
#                                            {'alpha': 2, 'beta': 1, 'gamma': 1},
#                                            {'alpha': 2, 'beta': 1, 'gamma': 3},
#                                            {'alpha': 2, 'beta': 1, 'gamma': 4},
#                                            {'alpha': 2, 'beta': 1, 'gamma': 5},
#                                            {'alpha': 2, 'beta': 2, 'gamma': 1},
#                                            {'alpha': 2, 'beta': 2, 'gamma': 3},
#                                            {'alpha': 2, 'beta': 2, 'gamma': 4},
#                                            {'alpha': 2, 'beta': 2, 'gamma': 5},
#                                            {'alpha': 2, 'beta': 3, 'gamma': 1},
#                                            {'alpha': 2, 'beta': 3, 'gamma': 3}, ...],
#                          'n_neighbors': [1]},
#              verbose=10)

# %%
grid_search_result = clf.cv_results_
grid_search_result_pd = pd.DataFrame.from_dict(grid_search_result)

# %%
grid_search_result_pd
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001991  3.576279e-06        69.665093        0.057497
# 1        0.000998  4.529953e-06        69.536099        0.257500
# 2        0.001006  2.384186e-07        69.708598        0.027002
# 3        0.001506  4.990101e-04        69.728102        0.032495
# 4        0.001998  3.218651e-06        68.978112        0.031503
# ..            ...           ...              ...             ...
# 95       0.001502  4.980564e-04        69.595234        0.415806
# 96       0.001004  3.099442e-06        47.726000        0.312504
# 97       0.000999  4.768372e-07        47.661977        0.135529
# 98       0.000496  4.963875e-04        46.813868        0.026006
# 99       0.001003  2.503395e-06        45.826862        0.888997
#
#                     param_metric_params param_n_neighbors  \
# 0   {'alpha': 1, 'beta': 1, 'gamma': 2}                 1
# 1   {'alpha': 1, 'beta': 1, 'gamma': 3}                 1
# 2   {'alpha': 1, 'beta': 1, 'gamma': 4}                 1
# 3   {'alpha': 1, 'beta': 1, 'gamma': 5}                 1
# 4   {'alpha': 1, 'beta': 2, 'gamma': 2}                 1
# ..                                  ...               ...
# 95  {'alpha': 5, 'beta': 4, 'gamma': 4}                 1
# 96  {'alpha': 5, 'beta': 5, 'gamma': 1}                 1
# 97  {'alpha': 5, 'beta': 5, 'gamma': 2}                 1
# 98  {'alpha': 5, 'beta': 5, 'gamma': 3}                 1
# 99  {'alpha': 5, 'beta': 5, 'gamma': 4}                 1
#
#                                                params  split0_test_score  \
# 0   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.666667
# 1   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.666667
# 2   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.666667
# 3   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.666667
# 4   {'metric_params': {'alpha': 1, 'beta': 2, 'gam...           0.466667
# ..                                                ...                ...
# 95  {'metric_params': {'alpha': 5, 'beta': 4, 'gam...           0.333333
# 96  {'metric_params': {'alpha': 5, 'beta': 5, 'gam...           0.400000
# 97  {'metric_params': {'alpha': 5, 'beta': 5, 'gam...           0.400000
# 98  {'metric_params': {'alpha': 5, 'beta': 5, 'gam...           0.400000
# 99  {'metric_params': {'alpha': 5, 'beta': 5, 'gam...           0.400000
#
#     split1_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.933333         0.800000        0.133333                1
# 1            0.933333         0.800000        0.133333                1
# 2            0.933333         0.800000        0.133333                1
# 3            0.933333         0.800000        0.133333                1
# 4            0.466667         0.466667        0.000000               21
# ..                ...              ...             ...              ...
# 95           0.466667         0.400000        0.066667               43
# 96           0.400000         0.400000        0.000000               43
# 97           0.400000         0.400000        0.000000               43
# 98           0.400000         0.400000        0.000000               43
# 99           0.400000         0.400000        0.000000               43
#
# [100 rows x 12 columns]

# %%
grid_search_result_pd[grid_search_result_pd['rank_test_score'] == 1]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001991  3.576279e-06        69.665093        0.057497
# 1        0.000998  4.529953e-06        69.536099        0.257500
# 2        0.001006  2.384186e-07        69.708598        0.027002
# 3        0.001506  4.990101e-04        69.728102        0.032495
# 20       0.001001  2.861023e-06        68.978699        0.164499
# 21       0.000998  1.192093e-06        69.088204        0.256004
# 22       0.001501  5.023479e-04        69.089700        0.257500
# 23       0.001500  4.975796e-04        69.199704        0.027501
# 40       0.000996  1.192093e-06        65.486922        0.073002
# 41       0.000501  5.006790e-04        65.397991        0.240072
# 42       0.000503  5.029440e-04        67.540583        0.174000
# 43       0.000997  5.006790e-06        66.742823        0.968761
# 60       0.001501  5.009174e-04        69.172022        0.135222
# 61       0.001000  3.099442e-06        69.561609        0.331367
# 62       0.000498  4.980564e-04        69.302469        0.235504
# 63       0.001000  3.576279e-07        69.598954        0.088023
# 80       0.000998  1.072884e-06        67.773411        0.191764
# 81       0.000997  2.384186e-07        67.784653        0.149003
# 82       0.001003  1.192093e-06        68.054646        0.100999
# 83       0.001003  4.649162e-06        68.351425        0.085785
#
#                     param_metric_params param_n_neighbors  \
# 0   {'alpha': 1, 'beta': 1, 'gamma': 2}                 1
# 1   {'alpha': 1, 'beta': 1, 'gamma': 3}                 1
# 2   {'alpha': 1, 'beta': 1, 'gamma': 4}                 1
# 3   {'alpha': 1, 'beta': 1, 'gamma': 5}                 1
# 20  {'alpha': 2, 'beta': 1, 'gamma': 1}                 1
# 21  {'alpha': 2, 'beta': 1, 'gamma': 3}                 1
# 22  {'alpha': 2, 'beta': 1, 'gamma': 4}                 1
# 23  {'alpha': 2, 'beta': 1, 'gamma': 5}                 1
# 40  {'alpha': 3, 'beta': 1, 'gamma': 1}                 1
# 41  {'alpha': 3, 'beta': 1, 'gamma': 2}                 1
# 42  {'alpha': 3, 'beta': 1, 'gamma': 4}                 1
# 43  {'alpha': 3, 'beta': 1, 'gamma': 5}                 1
# 60  {'alpha': 4, 'beta': 1, 'gamma': 1}                 1
# 61  {'alpha': 4, 'beta': 1, 'gamma': 2}                 1
# 62  {'alpha': 4, 'beta': 1, 'gamma': 3}                 1
# 63  {'alpha': 4, 'beta': 1, 'gamma': 5}                 1
# 80  {'alpha': 5, 'beta': 1, 'gamma': 1}                 1
# 81  {'alpha': 5, 'beta': 1, 'gamma': 2}                 1
# 82  {'alpha': 5, 'beta': 1, 'gamma': 3}                 1
# 83  {'alpha': 5, 'beta': 1, 'gamma': 4}                 1
#
#                                                params  split0_test_score  \
# 0   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.666667
# 1   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.666667
# 2   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.666667
# 3   {'metric_params': {'alpha': 1, 'beta': 1, 'gam...           0.666667
# 20  {'metric_params': {'alpha': 2, 'beta': 1, 'gam...           0.666667
# 21  {'metric_params': {'alpha': 2, 'beta': 1, 'gam...           0.666667
# 22  {'metric_params': {'alpha': 2, 'beta': 1, 'gam...           0.666667
# 23  {'metric_params': {'alpha': 2, 'beta': 1, 'gam...           0.666667
# 40  {'metric_params': {'alpha': 3, 'beta': 1, 'gam...           0.666667
# 41  {'metric_params': {'alpha': 3, 'beta': 1, 'gam...           0.666667
# 42  {'metric_params': {'alpha': 3, 'beta': 1, 'gam...           0.666667
# 43  {'metric_params': {'alpha': 3, 'beta': 1, 'gam...           0.666667
# 60  {'metric_params': {'alpha': 4, 'beta': 1, 'gam...           0.666667
# 61  {'metric_params': {'alpha': 4, 'beta': 1, 'gam...           0.666667
# 62  {'metric_params': {'alpha': 4, 'beta': 1, 'gam...           0.666667
# 63  {'metric_params': {'alpha': 4, 'beta': 1, 'gam...           0.666667
# 80  {'metric_params': {'alpha': 5, 'beta': 1, 'gam...           0.666667
# 81  {'metric_params': {'alpha': 5, 'beta': 1, 'gam...           0.666667
# 82  {'metric_params': {'alpha': 5, 'beta': 1, 'gam...           0.666667
# 83  {'metric_params': {'alpha': 5, 'beta': 1, 'gam...           0.666667
#
#     split1_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.933333              0.8        0.133333                1
# 1            0.933333              0.8        0.133333                1
# 2            0.933333              0.8        0.133333                1
# 3            0.933333              0.8        0.133333                1
# 20           0.933333              0.8        0.133333                1
# 21           0.933333              0.8        0.133333                1
# 22           0.933333              0.8        0.133333                1
# 23           0.933333              0.8        0.133333                1
# 40           0.933333              0.8        0.133333                1
# 41           0.933333              0.8        0.133333                1
# 42           0.933333              0.8        0.133333                1
# 43           0.933333              0.8        0.133333                1
# 60           0.933333              0.8        0.133333                1
# 61           0.933333              0.8        0.133333                1
# 62           0.933333              0.8        0.133333                1
# 63           0.933333              0.8        0.133333                1
# 80           0.933333              0.8        0.133333                1
# 81           0.933333              0.8        0.133333                1
# 82           0.933333              0.8        0.133333                1
# 83           0.933333              0.8        0.133333                1

# %%
model = clf.best_estimator_

# %%
print(model.get_params)
# Out:
# <bound method BaseEstimator.get_params of KNeighborsClassifier(metric=<function DTWWithWeightNeighborCell at 0x00000264DD976D40>,
#                      metric_params={'alpha': 1, 'beta': 1, 'gamma': 2},
#                      n_neighbors=1)>

# %%
y_pred = model.predict(X_test_sampling)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.83      1.00      0.91         5
#          2.0       0.82      1.00      0.90         9
#          3.0       1.00      0.25      0.40         4
#          4.0       0.92      0.92      0.92        12
#
#     accuracy                           0.87        30
#    macro avg       0.89      0.79      0.78        30
# weighted avg       0.88      0.87      0.84        30

# %% [markdown]
# Dump Best Asym Model

# %%
model_file = open('knn_Best_Asym_OliveOil.model', 'wb')
pickle.dump(model, model_file)
model_file.close()

# %% [markdown]
# จาก db OliveOil เราจะเห็นว่า Best ของ Asymmetric accuracy ดีกว่า Symmetric
